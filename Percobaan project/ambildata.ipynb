# %%
# !python -m pip install apify-client
# Out:
# ...
#   Using cached apify_client-2.2.1-py3-none-any.whl.metadata (18 kB)
# ...
#   Using cached apify_shared-2.1.0-py3-none-any.whl.metadata (14 kB)
# ...
#   Using cached impit-0.8.0-cp312-cp312-win_amd64.whl.metadata (2.9 kB)
# ...
# Using cached apify_client-2.2.1-py3-none-any.whl (86 kB)
# Using cached apify_shared-2.1.0-py3-none-any.whl (16 kB)
# Using cached impit-0.8.0-cp312-cp312-win_amd64.whl (3.9 MB)
# ...

# %%
# from apify_client import ApifyClient

# # Initialize the ApifyClient with your API token
# client = ApifyClient("APIFY_API_TOKEN")

# # Prepare the Actor input
# run_input = {
#     "commentsPerPost": 100,
#     "excludePinnedPosts": False,
#     "maxRepliesPerComment": 10,
#     "postURLs": [
#         "https://vt.tiktok.com/ZSyNUQbBA/"
#     ],
#     "resultsPerPage": 100
# }

# # Run the Actor and wait for it to finish
# run = client.actor("BDec00yAmCm1QbMEI").call(run_input=run_input)
# Out:
# [apify.tiktok-comments-scraper runId:CU1A4ErwCVK6DyXU4] -> Status: RUNNING, Message:
# [apify.tiktok-comments-scraper runId:CU1A4ErwCVK6DyXU4] -> 2025-10-31T06:39:04.960Z ACTOR: Pulling container image of build 9HnOGUzQiibYxPh8V from registry.
# [apify.tiktok-comments-scraper runId:CU1A4ErwCVK6DyXU4] -> 2025-10-31T06:39:04.961Z ACTOR: Creating container.
# [apify.tiktok-comments-scraper runId:CU1A4ErwCVK6DyXU4] -> 2025-10-31T06:39:05.671Z ACTOR: Starting container.
# [apify.tiktok-comments-scraper runId:CU1A4ErwCVK6DyXU4] -> 2025-10-31T06:39:05.884Z Will run command: xvfb-run -a -s "-ac -screen 0 1920x1080x24+32 -nolisten tcp" /bin/sh -c ./start_xvfb_and_run_cmd.sh && npm run start:prod --silent
# [apify.tiktok-comments-scraper runId:CU1A4ErwCVK6DyXU4] -> 2025-10-31T06:39:07.155Z INFO  System info {"apifyVersion":"3.4.2","apifyClientVersion":"2.12.6","crawleeVersion":"3.13.9","osType":"Linux","nodeVersion":"v20.19.5"}
# ...

# %%
items = list(client.dataset(run["defaultDatasetId"]).iterate_items())

# %%
import pandas as pd

df = pd.DataFrame(items)
df
# Out:
#                                           videoWebUrl  \
# 0   https://www.tiktok.com/@purbayayudhis/video/75...
# 1   https://www.tiktok.com/@purbayayudhis/video/75...
# 2   https://www.tiktok.com/@purbayayudhis/video/75...
# 3   https://www.tiktok.com/@purbayayudhis/video/75...
# 4   https://www.tiktok.com/@purbayayudhis/video/75...
# ..                                                ...
# 95  https://www.tiktok.com/@purbayayudhis/video/75...
# 96  https://www.tiktok.com/@purbayayudhis/video/75...
# 97  https://www.tiktok.com/@purbayayudhis/video/75...
# 98  https://www.tiktok.com/@purbayayudhis/video/75...
# 99  https://www.tiktok.com/@purbayayudhis/video/75...
#
#                    submittedVideoUrl                             input  \
# 0   https://vt.tiktok.com/ZSyNUQbBA/  https://vt.tiktok.com/ZSyNUQbBA/
# 1   https://vt.tiktok.com/ZSyNUQbBA/  https://vt.tiktok.com/ZSyNUQbBA/
# 2   https://vt.tiktok.com/ZSyNUQbBA/  https://vt.tiktok.com/ZSyNUQbBA/
# ...

# %%
# df.to_excel(r"D:\Dhika Ramadhan Saputra\UMP\Tugas Akhir (TA)\Percobaan project\data_coba.xlsx", index=False)
